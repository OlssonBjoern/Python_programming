# %%
import json
from json import JSONDecodeError, JSONEncoder

# %% [markdown]
# # JSON files

# %% [markdown]
# ### Loading JSON

# %%
jsonString = '{"a":"apple","b":"bear","c":"cat"}'
# If working with a not so trustworthy source, use try except
try:
    json.loads(jsonString)
except JSONDecodeError:
    print('Could not parse JSON!')

# %% [markdown]
# ### Dumping JSON

# %%
# Dumping a dictionary into a JSON string, use dumps

pythonDict = {"a":"apple","b":"bear","c":"cat"}
json.dumps(pythonDict)
# Out:
# '"{\\"a\\":\\"apple\\",\\"b\\":\\"bear\\",\\"c\\":\\"cat\\"}"'

# %% [markdown]
# ### Custom JSON decoders

# %%
class Animal:
    def __init__(self, name):
        self.name = name

class AnimalEncoder(JSONEncoder):
    def default(self, o):
        if type(o) == Animal:
            return o.name
        return super().default(o)

pythonDict = {"a": Animal('anaconda'),"b": Animal('bear'),"c": Animal('cockatoo')}
json.dumps(pythonDict, cls=AnimalEncoder)
# Out:
# '{"a": "anaconda", "b": "bear", "c": "cockatoo"}'
