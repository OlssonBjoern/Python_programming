# %% [markdown]
# # Data Structures

# %% [markdown]
# ### Lists

# %%
my_list = [1, 2, 3, 4]
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
string_list = ['Black Panther', 'Steve Rogers', 'Tony Stank']
mixed_list = ['The Hulk', 5, 'Moon Knight', 3, 1, 'Dr. Doom']

print(mixed_list[2])
# Out:
# Moon Knight

# %%
len(mixed_list)
# Out:
# 6

# %% [markdown]
# ### Sets

# %%
# All elements have to be unique in a set
my_set = {1, 2, 3, 4, 5}
print(my_set)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(my_set)
# Out:
# list

# %%
new_set = {1, 1, 3, 4, 4}
print(new_set)
# Out:
# {1, 3, 4}

# %%
# True eventhough they are not the same order 
{1, 2} == {2, 1}
# Out:
# True

# %% [markdown]
# ### Tuples

# %%
# Tuples have a length, but can't append or add things to it
my_tuple = (1, 2, 3)
len(my_tuple)
# Out:
# 3

# %%
(1, 3) == (3, 1)
# Out:
# False

# %%
my_list.append(6)
print(my_list)
# Out:
# [1, 2, 3, 4, 6]

# %% [markdown]
# ### Dictionaries

# %%
my_dictionary = {
    'apple' : 'A red fruit',
    'bear' : 'A brown animal'
}

# %%
my_dictionary['apple']
# Out:
# 'A red fruit'

# %%
marvel_dict = {
    'Hulk' : 'Bruce Banner',
    'Mr.Fantastic' : 'Reed Richards',
    'Iron Man' : 'Tony Stark',
    'Black Panther' : 'T\'Challa'
}

# %%
print('Real name of  the Hulk is: ' + marvel_dict['Hulk'])
# Out:
# Real name of  the Hulk is: Bruce Banner
