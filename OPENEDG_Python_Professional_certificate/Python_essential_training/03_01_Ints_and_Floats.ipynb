# %% [markdown]
# ### Ints and Floats

# %%
20 / 4
# Out:
# 5.0

# %%
4 + 4.0
# Out:
# 8.0

# %%
4 ** 4.0
# Out:
# 256.0

# %%
round(1.2-1.0, 2)
# Out:
# 0.2

# %%
int('100')
# Out:
# 100

# %%
# 2 here is the base
# 100 in base 2, is 4 in base 10
int('100', 2)
# Out:
# 4

# %%
# 16 is the base "HEX"
# And 1ab means 1 10 11 in HEX
int('1ab', 16)
# Out:
# 427
