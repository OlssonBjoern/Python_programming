# %% [markdown]
# # Tuples and sets

# %%
mySet = {'a', 'b', 'c'}
mySet
# Out:
# {'a', 'b', 'c'}

# %%
mySet = set(('a', 'b', 'c'))

# %%
mySet
# Out:
# {'a', 'b', 'c'}

# %%
myList = ['a', 'b', 'c', 'c', 'd']
myList = list(set(myList))
myList
# Out:
# ['a', 'd', 'b', 'c']

# %%
# Adding to set does not use append
mySet.add('r')
mySet
# Out:
# {'a', 'b', 'c', 'r'}

# %%
# Checking for elements
'a' in mySet
# Out:
# True

# %%
'z' in mySet
# Out:
# False

# %%
len(mySet)
# Out:
# 4

# %%
while len(mySet):
    print(mySet.pop())

# %% [markdown]
# ### Tuples

# %%
# Can't modify a tuple
myTuple = ('a', 'b', 'c')
myTuple
# Out:
# ('a', 'b', 'c')
