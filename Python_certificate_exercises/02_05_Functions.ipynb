# %% [markdown]
# ## Functions

# %%
# Make function that multiplies by 3
def multiplyByThree(val):
    return 3 * val

multiplyByThree(4)
# Out:
# 12

# %%
# Mutation
a = [1, 2, 3]

def appendFour(myList):
    myList.append(4)

appendFour(a)
print(a)
# Out:
# [1, 2, 3, 4]
